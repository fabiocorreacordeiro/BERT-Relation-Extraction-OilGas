# %%
# Conectar o Colab ao Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Acessar o diretório dos repositórios
# %cd /content/drive/MyDrive/Estudo/Doutorado_FGV-EMAp/Dissertação/Repositórios/BERT-Relation-Extraction-OilGas
# Out:
# /content/drive/MyDrive/Estudo/Doutorado_FGV-EMAp/Dissertação/Repositórios/BERT-Relation-Extraction-OilGas

# %%
#Instalando bibliotecas
% pip install  boto3
# Out:
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (1.18.43)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3) (0.10.0)
# Requirement already satisfied: botocore<1.22.0,>=1.21.43 in /usr/local/lib/python3.7/dist-packages (from boto3) (1.21.43)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from boto3) (0.5.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.22.0,>=1.21.43->boto3) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.7/dist-packages (from botocore<1.22.0,>=1.21.43->boto3) (1.26.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.22.0,>=1.21.43->boto3) (1.15.0)

# %%
# Importando bibliotecas
import main_pretraining

# %%
# Importando modelo do spaCy
# %run -m spacy download pt_core_news_sm
# Out:
# ✔ Download and installation successful
# You can now load the model via spacy.load('pt_core_news_sm')

# %%
# %run main_pretraining.py --num_epochs 1 --pretrain_data 'data/corpusPublico(sem IBICT)-small.txt'
# Out:
# 09/17/2021 07:18:20 PM [INFO]: Loading pre-training data...
# 09/17/2021 07:18:22 PM [INFO]: Length of text (characters): 494077
# 09/17/2021 07:18:22 PM [INFO]: Splitting into 10 max length chunks of size 50000
# 09/17/2021 07:18:22 PM [INFO]: Loading Spacy NLP...
#   0%|          | 0/10 [00:00<?, ?it/s]09/17/2021 07:18:25 PM [INFO]: Processing sentences...
# 09/17/2021 07:18:26 PM [INFO]: Processing relation statements by entities...
#
# 100%|██████████| 249/249 [00:00<00:00, 3787.22it/s]
# 09/17/2021 07:18:26 PM [INFO]: Processing relation statements by dependency tree parsing...
# Processed dataset samples from named entity extraction:
# ((['GÁS', 'NATURAL', 'DE', 'ORIGEM', 'NACIONAL', 'PETROBRAS', 'Produtor', 'Transportador', 'Não', 'há', 'contratos', 'de', 'Transporte', 'Firmados', 'Carregador', 'Distribuidor', 'Contratos', 'de', 'Compra', 'e', 'Venda', 'Redação', 'dada', 'pela', 'Emenda', 'Constitucional', 'n', 'o5', 'de', '.'], (1, 2), (24, 26)), 'NATURAL', 'Emenda Constitucional')
#
# ((['De', 'acordo', 'com', 'perspectivas', 'dos', 'principais', 'distribuidores', 'do', 'país', 'a', 'Comgás', 'SP', 'e', 'investimento', 'previsto', 'para', 'o', 'ano', 'de', 'é', 'de', 'R247', 'milhões', 'e', 'CEG', 'CEGRio', 'RJ', 'o', 'R140', 'milhões', 'respectivamente', '.'], (10, 12), (24, 27)), 'Comgás SP', 'CEG CEGRio RJ')
#
# ((['PARTICIPAÇÕES', 'CRUZADAS', 'NA', 'INDÚSTRIA', 'BRASILEIRA', 'DE', 'GÁS', 'NATURAL', 'fevereiro', 'Participações', 'Cruzadas', 'no', 'Setor', 'de', 'Gás', 'Natural', 'PARTICIPAÇÕES', 'CRUZADAS', 'NA', 'INDÚSTRIA', 'BRASILEIRA', 'DE', 'GÁS', 'NATURAL', 'Superintendência', 'de', 'Comercialização', 'e', 'Movimentação', 'de', 'Gás', 'Natural', 'SCG', 'ANP', 'Fevereiro', '.'], (19, 20), (28, 33)), 'INDÚSTRIA', 'Movimentação de Gás Natural SCG')
# 100%|██████████| 536/536 [00:00<00:00, 64799.30it/s]
#  10%|█         | 1/10 [00:01<00:14,  1.66s/it]09/17/2021 07:18:26 PM [INFO]: Processing sentences...
# Processed dataset samples from dependency tree parsing:
# 09/17/2021 07:18:28 PM [INFO]: Processing relation statements by entities...
#
#   0%|          | 0/338 [00:00<?, ?it/s]
# 100%|██████████| 338/338 [00:00<00:00, 1820.73it/s]
# 09/17/2021 07:18:28 PM [INFO]: Processing relation statements by dependency tree parsing...
# Processed dataset samples from named entity extraction:
# ((['Reliant', 'Energy', 'Inc', '.', 'Williams', 'Companies', 'Inc', '.', 'TOTAL', 'Fonte', 'EIA', '.'], (0, 3), (10, 11)), 'Reliant Energy Inc', 'EIA')
#
# ((['No', 'caso', 'específico', 'do', 'Concurso', 'Aberto', 'para', 'expansão', 'de', 'capacidade', 'de', 'transporte', 'a', 'ANP', 'está', 'acompanhando', 'o', 'processo', 'de', 'elaboração', 'dos', 'Termos', 'e', 'Condições', 'Gerais', 'para', 'a', 'prestação', 'dos', 'serviços', 'de', 'transporte', '.'], (21, 22), (23, 25)), 'Termos', 'Condições Gerais')
#
# ((['No', 'caso', 'específico', 'do', 'Concurso', 'Aberto', 'para', 'expansão', 'de', 'capacidade', 'de', 'transporte', 'a', 'ANP', 'está', 'acompanhando', 'o', 'processo', 'de', 'elaboração', 'dos', 'Termos', 'e', 'Condições', 'Gerais', 'para', 'a', 'prestação', 'dos', 'serviços', 'de', 'transporte', '.'], (13, 14), (23, 25)), 'ANP', 'Condições Gerais')
# 100%|██████████| 620/620 [00:00<00:00, 184012.77it/s]
#  20%|██        | 2/10 [00:03<00:13,  1.71s/it]09/17/2021 07:18:28 PM [INFO]: Processing sentences...
# Processed dataset samples from dependency tree parsing:
# 09/17/2021 07:18:30 PM [INFO]: Processing relation statements by entities...
#
#   0%|          | 0/567 [00:00<?, ?it/s]
# 100%|██████████| 567/567 [00:00<00:00, 3482.41it/s]
# 09/17/2021 07:18:30 PM [INFO]: Processing relation statements by dependency tree parsing...
# Processed dataset samples from named entity extraction:
# ((['Brasília', 'SEAE', 'MF', 'Documento', 'de', 'Trabalho', 'n', 'Dez', '.', 'Ilícito', 'Antitruste', 'e', 'acordos', 'entre', 'concorrentes', '.', 'Ensaios', 'sobre', 'Economia', 'e', 'Direito', 'da', 'Concorrência', '.', 'São', 'Paulo', 'Singular', '.'], (0, 1), (24, 27)), 'Brasília', 'São Paulo Singular')
#
# ((['dez', '1995', 'dez', 'dez', '2000', 'dez', 'dez', '2003', 'dez', '0', '0', '0', '0', '0', 'C.', 'Resíduo', 'IVC', 'Figura', '.', 'Contribuições', 'da', 'Renda', 'do', 'Preço', 'da', 'Indústria', 'e', 'do', 'Resíduo', 'vs', 'o', 'IVC', '.'], (14, 18), (31, 32)), 'C. Resíduo IVC Figura', 'IVC')
#
# ((['São', 'Paulo', 'Singular', '.', 'Detecção', 'de', 'Cartéis', 'e', 'Experiência', 'Brasileira', 'Recente', '.'], (0, 3), (6, 7)), 'São Paulo Singular', 'Cartéis')
# 100%|██████████| 821/821 [00:00<00:00, 69166.50it/s]
#  30%|███       | 3/10 [00:05<00:12,  1.82s/it]09/17/2021 07:18:30 PM [INFO]: Processing sentences...
# Processed dataset samples from dependency tree parsing:
# 09/17/2021 07:18:32 PM [INFO]: Processing relation statements by entities...
#
#   0%|          | 0/460 [00:00<?, ?it/s]
#  32%|███▏      | 145/460 [00:00<00:00, 1428.47it/s]
# 100%|██████████| 460/460 [00:00<00:00, 2053.15it/s]
# 09/17/2021 07:18:32 PM [INFO]: Processing relation statements by dependency tree parsing...
# Processed dataset samples from named entity extraction:
# ((['Com', 'a', 'publicação', 'da', 'Lei', 'do', 'Petróleo', 'atividades', 'de', 'exploração', 'e', 'produção', 'E&P', 'de', 'hidrocarbonetos', 'passaram', 'a', 'ser', 'concessões', 'e', 'podiam', 'ingressar', 'n', 'essas', 'atividades', 'agentes', 'que', 'fossem', 'vitoriosos', 'nos', 'Leilões', 'de', 'Blocos', 'promovidos', 'anualmente', 'pela', 'ANP', '.'], (30, 33), (36, 37)), 'Leilões de Blocos', 'ANP')
#
# ((['A', 'Lei', 'estabeleceu', 'ainda', 'que', 'o', 'monopólio', 'seria', 'exercido', 'pela', 'Petrobras', 'órgão', 'executor', 'do', 'monopólio', 'da', 'União', 'e', 'pelo', 'CNP', 'na', 'fiscalização', 'das', 'atividades', 'decorrentes', 'do', 'monopólio', '.'], (10, 11), (16, 17)), 'Petrobras', 'União')
#
# ((['MACHADO', 'apresenta', 'uma', 'revisão', 'da', 'literatura', 'de', 'hidratos', 'de', 'gás', 'e', 'considera', 'grandes', 'as', 'probabilidades', 'de', 'que', 'sejam', 'encontrados', 'nas', 'bacias', 'sedimentares', 'de', 'Campos', 'Espírito', 'Santo', 'e', 'Cumuruxatiba', '.'], (23, 26), (27, 28)), 'Campos Espírito Santo', 'Cumuruxatiba')
# 100%|██████████| 658/658 [00:00<00:00, 93760.90it/s]
#  40%|████      | 4/10 [00:07<00:10,  1.81s/it]09/17/2021 07:18:32 PM [INFO]: Processing sentences...
# Processed dataset samples from dependency tree parsing:
# 09/17/2021 07:18:33 PM [INFO]: Processing relation statements by entities...
#
#   0%|          | 0/443 [00:00<?, ?it/s]
#  16%|█▋        | 72/443 [00:00<00:00, 716.40it/s]
#  33%|███▎      | 144/443 [00:00<00:00, 684.94it/s]
#  50%|█████     | 222/443 [00:00<00:00, 724.62it/s]
# 100%|██████████| 443/443 [00:00<00:00, 1027.26it/s]
# 09/17/2021 07:18:34 PM [INFO]: Processing relation statements by dependency tree parsing...
# Processed dataset samples from named entity extraction:
# ((['As', 'instalações', 'em', 'operação', 'ou', 'em', 'fase', 'final', 'de', 'implantação', 'são', 'no', 'País', 'de', 'Gales', 'a', 'Dragon', 'LNG17', 'e', 'a', 'South', 'Hook', 'e', 'na', 'Inglaterra', 'a', 'Norsea', 'e', 'a', 'Isle', 'of', 'Grain', '.'], (24, 25), (26, 27)), 'Inglaterra', 'Norsea')
#
# ((['Além', 'da', 'Snam', 'Rete', 'Gas', 'existem', 'duas', 'outras', 'companhias', 'realizam', 'a', 'atividade', 'de', 'importação', 'de', 'gás', 'na', 'Itália', 'a', 'Edison', 'com', 'importações', 'da', 'Rússia', 'Noruega', 'Líbia', 'e', 'Qatar', 'GNL', 'e', 'Enel', 'com', 'importações', 'da', 'Argélia', 'e', 'Nigéria', '.'], (17, 18), (23, 24)), 'Itália', 'Rússia')
#
# ((['Além', 'd', 'isso', 'as', 'companhias', 'comercializadoras', 'devem', 'ser', 'registradas', 'no', 'Registro', 'Administrativo', 'de', 'Distribuidores', 'Comercializadores', 'e', 'Consumidores', 'Elegíveis', 'Administrative', 'Registry', 'of', 'Distributors', 'Wholesalers', 'e', 'Eligible', 'Costumers', 'registro', 'este', 'gerido', 'pelo', 'Ministério', 'da', 'Indústria', '.'], (24, 26), (30, 33)), 'Eligible Costumers', 'Ministério da Indústria')
# 100%|██████████| 473/473 [00:00<00:00, 93053.74it/s]
#  50%|█████     | 5/10 [00:09<00:09,  1.88s/it]09/17/2021 07:18:34 PM [INFO]: Processing sentences...
# Processed dataset samples from dependency tree parsing:
# 09/17/2021 07:18:35 PM [INFO]: Processing relation statements by entities...
#
# 100%|██████████| 289/289 [00:00<00:00, 3008.41it/s]
# 09/17/2021 07:18:35 PM [INFO]: Processing relation statements by dependency tree parsing...
# Processed dataset samples from named entity extraction:
# ((['Caso', 'o', 'projeto', 'proposto', 'esteja', 'localizado', 'em', 'águas', 'federais', 'a', 'Guarda', 'Costeira', 'Norte', 'Americana', 'e', 'a', 'Administração', 'Marítima', 'têm', 'a', 'jurisdição', 'sobre', 'a', 'instalação', 'e', 'operação', 'do', 'terminal', 'de', 'GNL', 'tal', 'como', 'disposto', 'no', 'Deepwater', 'Ports', 'Act', 'de', '.'], (10, 14), (34, 36)), 'Guarda Costeira Norte Americana', 'Deepwater Ports')
#
# ((['Face', 'a', 'o', 'exposto', 'as', 'solicitações', 'de', 'outorga', 'de', 'Autorizações', 'de', 'Construção', 'Operação', 'foram', 'formalizadas', 'pela', 'TAG', 'empresa', 'subsidiária', 'da', 'Petrobras', 'e', 'cujo', 'objeto', 'social', 'é', 'a', 'atividade', 'de', 'transporte', 'de', 'gás', 'natural', '.'], (9, 13), (20, 21)), 'Autorizações de Construção Operação', 'Petrobras')
#
# ((['Caso', 'o', 'projeto', 'proposto', 'esteja', 'localizado', 'em', 'águas', 'federais', 'a', 'Guarda', 'Costeira', 'Norte', 'Americana', 'e', 'a', 'Administração', 'Marítima', 'têm', 'a', 'jurisdição', 'sobre', 'a', 'instalação', 'e', 'operação', 'do', 'terminal', 'de', 'GNL', 'tal', 'como', 'disposto', 'no', 'Deepwater', 'Ports', 'Act', 'de', '.'], (10, 14), (16, 18)), 'Guarda Costeira Norte Americana', 'Administração Marítima')
# 100%|██████████| 443/443 [00:00<00:00, 64297.76it/s]
#  60%|██████    | 6/10 [00:10<00:07,  1.79s/it]09/17/2021 07:18:35 PM [INFO]: Processing sentences...
# Processed dataset samples from dependency tree parsing:
# 09/17/2021 07:18:37 PM [INFO]: Processing relation statements by entities...
#
#   0%|          | 0/617 [00:00<?, ?it/s]
#  13%|█▎        | 78/617 [00:00<00:00, 763.12it/s]
#  25%|██▌       | 155/617 [00:00<00:00, 756.59it/s]
#  41%|████      | 253/617 [00:00<00:00, 854.16it/s]
# 100%|██████████| 617/617 [00:00<00:00, 1233.37it/s]
# 09/17/2021 07:18:37 PM [INFO]: Processing relation statements by dependency tree parsing...
# Processed dataset samples from named entity extraction:
# ((['Outrossim', 'como', 'tal', 'norma', 'se', 'dirige', 'a', 'os', 'Transportadores', 'de', 'gás', 'natural', 'cabe', 'repensá', 'la', 'com', 'vistas', 'a', 'abranger', 'também', 'os', 'novos', 'agentes', 'sob', 'a', 'égide', 'da', 'ANP', 'Carregadores', 'e', 'Comercializadores', '.'], (27, 29), (30, 31)), 'ANP Carregadores', 'Comercializadores')
#
# ((['Para', 'as', 'despesas', 'Gerais', '&', 'Administrativas', 'G&A', 'foi', 'adotado', 'o', 'valor', 'anual', 'de', 'R', 'milhões', 'vinte', 'e', 'dois', 'milhões', 'e', 'setecentos', 'mil', 'reais', 'ix', '.'], (3, 7), (13, 14)), 'Gerais & Administrativas G&A', 'R')
#
# ((['Custos', 'de', 'O&M', 'Despesas', 'Gerais', 'e', 'Administrativas', 'Depreciação', 'LAIR', 'CS', 'IR', 'Lucro', 'Líquido', '.', 'Valor', 'Residual', 'Necessidade', 'Líquida', 'de', 'Capital', 'de', 'Giro', '0', '0', 'Investimentos', 'Fluxo', 'de', 'Caixa', 'Livre', 'da', 'Firma', 'Fonte', 'TAG', '........'], (3, 5), (19, 20)), 'Despesas Gerais', 'Capital')
# 100%|██████████| 562/562 [00:00<00:00, 88047.17it/s]
#  70%|███████   | 7/10 [00:12<00:05,  1.87s/it]09/17/2021 07:18:37 PM [INFO]: Processing sentences...
# Processed dataset samples from dependency tree parsing:
# ((['o', 'qual', 'exige', 'que', 'terminais', 'marítimos', 'para', 'transporte', 'sejam', 'construídos', 'e', 'operados', 'por', 'subsidiária', 'da', 'Petrobras', 'constituída', 'com', 'fins', 'específicos', 'para', 'tal', 'atividade', '.'], (0, 2), (3, 6)), 'o qual', 'que terminais marítimos')
#
# ((['nossos', 'Vale', 'destacar', 'que', 'o', 'supracitado', 'artigo', 'não', 'sofreu', 'qualquer', 'alteração', 'com', 'a', 'publicação', 'da', 'Lei', 'do', 'Gás', 'e', 'portanto', 'continua', 'válido', 'na', 'íntegra', '.'], (0, 2), (21, 24)), 'nossos Vale', 'válido na íntegra')
# 09/17/2021 07:18:39 PM [INFO]: Processing relation statements by entities...
#
#   0%|          | 0/620 [00:00<?, ?it/s]
#  12%|█▏        | 73/620 [00:00<00:00, 722.29it/s]
#  24%|██▎       | 147/620 [00:00<00:00, 726.27it/s]
#  35%|███▌      | 220/620 [00:00<00:00, 672.59it/s]
#  48%|████▊     | 300/620 [00:00<00:00, 717.70it/s]
# 100%|██████████| 620/620 [00:00<00:00, 1031.78it/s]
# 09/17/2021 07:18:40 PM [INFO]: Processing relation statements by dependency tree parsing...
# Processed dataset samples from named entity extraction:
# ((['São', 'Paulo', 'Revista', 'do', 'IBRAC', 'p.', 'BORGES', 'HELOISA', '.', 'A', 'Interação', 'entre', 'CADE', 'ANEEL', 'e', 'ANP', 'na', 'Defesa', 'da', 'Concorrência', '.'], (4, 5), (10, 14)), 'IBRAC', 'Interação entre CADE ANEEL')
#
# ((['São', 'Paulo', 'Revista', 'do', 'IBRAC', 'p.', 'BORGES', 'HELOISA', '.', 'A', 'Interação', 'entre', 'CADE', 'ANEEL', 'e', 'ANP', 'na', 'Defesa', 'da', 'Concorrência', '.', 'Boletim', 'PETRÓLEO', '&'], (0, 3), (21, 23)), 'São Paulo Revista', 'Boletim PETRÓLEO')
#
# ((['Como', 'se', 'observa', 'o', 'valor', 'constante', 'da', 'Tabela', 'é', 'superior', 'a', 'o', 'estimado', 'pela', 'Nota', 'Técnica', 'n', '2010', 'SCM', 'R', 'MMBtu', '.'], (7, 8), (18, 19)), 'Tabela', 'SCM')
# 100%|██████████| 634/634 [00:00<00:00, 64640.69it/s]
#  80%|████████  | 8/10 [00:14<00:03,  1.97s/it]09/17/2021 07:18:40 PM [INFO]: Processing sentences...
# Processed dataset samples from dependency tree parsing:
# 09/17/2021 07:18:43 PM [INFO]: Processing relation statements by entities...
#
#   0%|          | 0/287 [00:00<?, ?it/s]
# 100%|██████████| 287/287 [00:00<00:00, 2138.42it/s]
# 09/17/2021 07:18:43 PM [INFO]: Processing relation statements by dependency tree parsing...
# Processed dataset samples from named entity extraction:
# ((['SOBRE', 'A', 'EXISTÊNCIA', 'DE', 'PODER', 'DE', 'MERCADO', 'E', 'DA', 'APTIDÃO', 'PARA', 'AFETAR', 'A', 'CONCORRÊNCIA', '.', 'CONCEITOS', 'BÁSICOS', 'DE', 'PRÁTICAS', 'RESTRITIVAS', 'VERTICAIS', '.', 'PRÁTICAS', 'RESTRITIVAS', 'VERTICAIS', 'NAS', 'INDÚSTRIAS', 'DE', 'REDE', '.', 'A', 'INDÚSTRIA', 'DO', 'GÁS', 'NATURAL', 'NO', 'BRASIL', '.'], (13, 14), (36, 37)), 'CONCORRÊNCIA', 'BRASIL')
#
# ((['Texto', 'para', 'Discussão', 'n', 'Instituto', 'de', 'Economia', 'UFRJ', '.', 'Defesa', 'da', 'concorrência', 'no', 'setor', 'elétrico', '.', 'São', 'Paulo', 'Revista', 'do', 'IBRAC', 'p.', 'Helder', 'Queiroz', 'FIANI', 'Ronaldo', '.', 'In', 'KUPFER', 'David', '.', 'Economia', 'Industrial', 'fundamentos', 'teóricos', 'e', 'práticas', 'no', 'Brasil', '.'], (2, 3), (38, 39)), 'Discussão', 'Brasil')
#
# ((['ESTRUTURA', 'DA', 'INDÚSTRIA', 'BRASILEIRA', 'DO', 'GÁS', 'NATURAL', '.', 'O', 'MERCADO', 'DE', 'GÁS', 'NATURAL', 'NO', 'BRASIL', '.', 'Mercado', 'de', 'Distribuição', 'de', 'Gás', 'Canalizado', '.', 'PARTICIPAÇÕES', 'DA', 'PETROBRAS', 'NA', 'INDÚSTRIA', 'DO', 'GÁS', 'NATURAL', 'NO', 'BRASIL', '.'], (2, 4), (32, 33)), 'INDÚSTRIA BRASILEIRA', 'BRASIL')
# 100%|██████████| 502/502 [00:00<00:00, 75763.40it/s]
#  90%|█████████ | 9/10 [00:18<00:02,  2.53s/it]09/17/2021 07:18:43 PM [INFO]: Processing sentences...
# Processed dataset samples from dependency tree parsing:
# 09/17/2021 07:18:45 PM [INFO]: Processing relation statements by entities...
#
# 100%|██████████| 177/177 [00:00<00:00, 4750.33it/s]
# 09/17/2021 07:18:45 PM [INFO]: Processing relation statements by dependency tree parsing...
# Processed dataset samples from named entity extraction:
# ((['Para', 'mais', 'informações', 'ver', 'COASE', 'R.', 'The', 'Nature', 'of', 'the', 'Firm', 'Economica', '.', 'A', 'INDÚSTRIA', 'DO', 'GÁS', 'NATURAL', 'NO', 'BRASIL', '.'], (4, 5), (16, 18)), 'COASE', 'GÁS NATURAL')
#
# ((['Contudo', 'devido', 'a', 'problemas', 'relacionados', 'a', 'o', 'abastecimento', 'interno', 'na', 'Argentina', 'e', 'na', 'Bolívia', 'a', 'importação', 'de', 'origem', 'Argentina', 'está', 'suspensa', 'desde', 'meados', 'de', 'e', 'a', 'importação', 'via', 'Lateral', 'Cuiabá', 'foi', 'reduzida', 'à', 'valores', 'pouco', 'significativos26', '.'], (10, 11), (13, 14)), 'Argentina', 'Bolívia')
#
# ((['No', 'caso', 'da', 'importação', 'dutoviária', 'o', 'país', 'detém', 'infraestrutura', 'para', 'importar', 'gás', 'de', 'origem', 'Argentina', 'por', 'meio', 'do', 'Uruguaiana', 'Porto', 'Alegre', 'trecho', 'e', 'gás', 'proveniente', 'da', 'Bolívia', 'através', 'dos', 'gasodutos', 'Lateral', 'Cuiabá', 'e', 'Bolívia', 'Brasil', 'GASBOL', '.'], (14, 15), (33, 36)), 'Argentina', 'Bolívia Brasil GASBOL')
# 100%|██████████| 373/373 [00:00<00:00, 151979.35it/s]
# 100%|██████████| 10/10 [00:20<00:00,  2.02s/it]
# 09/17/2021 07:18:45 PM [INFO]: Total number of relation statements in pre-training corpus: 625
# 09/17/2021 07:18:45 PM [INFO]: Saved pre-training corpus to ./data/D.pkl
# Processed dataset samples from dependency tree parsing:
# 09/17/2021 07:18:48 PM [INFO]: TensorFlow version 2.6.0 available.
# 09/17/2021 07:18:48 PM [INFO]: PyTorch version 1.9.0+cu102 available.
# 09/17/2021 07:18:49 PM [INFO]: https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt not found in cache or force_download set to True, downloading to /tmp/tmptiunayqo
# 100%|██████████| 231508/231508 [00:00<00:00, 698524.65B/s]
# 09/17/2021 07:18:50 PM [INFO]: copying /tmp/tmptiunayqo to cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 09/17/2021 07:18:50 PM [INFO]: creating metadata file for /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 09/17/2021 07:18:50 PM [INFO]: removing temp file /tmp/tmptiunayqo
# 09/17/2021 07:18:50 PM [INFO]: loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 09/17/2021 07:18:50 PM [INFO]: Adding [E1] to the vocabulary
# 09/17/2021 07:18:50 PM [INFO]: Adding [/E1] to the vocabulary
# 09/17/2021 07:18:50 PM [INFO]: Adding [E2] to the vocabulary
# 09/17/2021 07:18:50 PM [INFO]: Adding [/E2] to the vocabulary
# 09/17/2021 07:18:50 PM [INFO]: Adding [BLANK] to the vocabulary
# 09/17/2021 07:18:50 PM [INFO]: Saved BERT tokenizer at ./data/BERT_tokenizer.pkl
# 09/17/2021 07:18:50 PM [INFO]: Loaded 625 pre-training samples.
# 09/17/2021 07:18:52 PM [INFO]: https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json not found in cache or force_download set to True, downloading to /tmp/tmp2pceidv4
# 100%|██████████| 433/433 [00:00<00:00, 317062.44B/s]
# 09/17/2021 07:18:52 PM [INFO]: copying /tmp/tmp2pceidv4 to cache at /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 09/17/2021 07:18:52 PM [INFO]: creating metadata file for /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 09/17/2021 07:18:52 PM [INFO]: removing temp file /tmp/tmp2pceidv4
# 09/17/2021 07:18:52 PM [INFO]: loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 09/17/2021 07:18:52 PM [INFO]: Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pruned_heads": {},
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
#
# 09/17/2021 07:18:53 PM [INFO]: https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin not found in cache or force_download set to True, downloading to /tmp/tmp0eb5uit5
# 100%|██████████| 440473133/440473133 [00:17<00:00, 25661363.98B/s]
# 09/17/2021 07:19:10 PM [INFO]: copying /tmp/tmp0eb5uit5 to cache at /root/.cache/torch/transformers/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 09/17/2021 07:19:11 PM [INFO]: creating metadata file for /root/.cache/torch/transformers/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# 09/17/2021 07:19:11 PM [INFO]: removing temp file /tmp/tmp0eb5uit5
# 09/17/2021 07:19:12 PM [INFO]: loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/transformers/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# Model config:  {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pruned_heads": {},
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
# 09/17/2021 07:19:14 PM [INFO]: Weights of BertModel not initialized from pretrained model: ['bert.cls.predictions.bias', 'bert.cls.predictions.transform.dense.weight', 'bert.cls.predictions.transform.dense.bias', 'bert.cls.predictions.transform.LayerNorm.weight', 'bert.cls.predictions.transform.LayerNorm.bias', 'bert.cls.predictions.decoder.weight']
# 09/17/2021 07:19:24 PM [INFO]: Starting training process...
# 09/17/2021 07:19:44 PM [INFO]: Last batch samples (pos, neg): 1, 5
# LM loss, blank_loss for last batch: 4.61759, 4.16666
# [Epoch: 1,    62/ 625 points] total loss, lm accuracy per batch: 15.172, 0.482
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/drive/My Drive/Estudo/Doutorado_FGV-EMAp/Dissertação/Repositórios/BERT-Relation-Extraction-OilGas/main_pretraining.py in <module>()
#      43     args = parser.parse_args()
#      44
# ---> 45     output = train_and_fit(args)
#      46
#      47     '''
#
# /content/drive/My Drive/Estudo/Doutorado_FGV-EMAp/Dissertação/Repositórios/BERT-Relation-Extraction-OilGas/src/trainer.py in train_and_fit(args)
#     149                 grad_norm = torch.nn.utils.clip_grad_norm_(amp.master_params(optimizer), args.max_norm)
#     150             else:
# --> 151                 grad_norm = clip_grad_norm_(net.parameters(), args.max_norm)
#     152
#     153             if (i % args.gradient_acc_steps) == 0:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/utils/clip_grad.py in clip_grad_norm_(parameters, max_norm, norm_type, error_if_nonfinite)
#      41     else:
#      42         total_norm = torch.norm(torch.stack([torch.norm(p.grad.detach(), norm_type).to(device) for p in parameters]), norm_type)
# ---> 43     if total_norm.isnan() or total_norm.isinf():
#      44         if error_if_nonfinite:
#      45             raise RuntimeError(
#
# KeyboardInterrupt:

# %%
# Examples:

import torch
from src.model.BERT.tokenization_bert import BertTokenizer
from src.model.BERT.modeling_bert import BertModel

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')
input_ids = torch.tensor(tokenizer.encode("Hello, my dog is cute")).unsqueeze(0)  # Batch size 1
#outputs = model(input_ids)
#last_hidden_states = outputs[0]  # The last hidden-state is the first element of the output tuple
input_ids
# Out:
# 09/17/2021 06:27:00 PM [INFO]: loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /root/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 09/17/2021 06:27:00 PM [INFO]: loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 09/17/2021 06:27:00 PM [INFO]: Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pruned_heads": {},
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
#
# 09/17/2021 06:27:00 PM [INFO]: loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/transformers/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-8e2c8950639b> in <module>()
#       6
#       7 tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# ----> 8 model = BertModel.from_pretrained('bert-base-uncased')
#       9 input_ids = torch.tensor(tokenizer.encode("Hello, my dog is cute")).unsqueeze(0)  # Batch size 1
#      10 #outputs = model(input_ids)
#
# /content/drive/My Drive/Estudo/Doutorado_FGV-EMAp/Dissertação/Repositórios/BERT-Relation-Extraction-OilGas/src/model/BERT/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     390
#     391         # Instantiate model.
# --> 392         model = cls(config, *model_args, **model_kwargs)
#     393
#     394         if state_dict is None and not from_tf:
#
# TypeError: __init__() missing 1 required positional argument: 'model_size'

# %%
from src.model.BERT.modeling_bert import BertModel as Model
model = 'bert-base-uncased' #args.model_size #
lower_case = True
model_name = 'BERT'
net = Model.from_pretrained(model, force_download=False, \
                        model_size= 'bert-base-uncased', #args.model_size,
                        task='classification',# if args.task != 'fewrel' else 'fewrel',\
                        n_classes_= 2)# args.num_classes)
# Out:
# 09/17/2021 06:19:13 PM [INFO]: loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /root/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 09/17/2021 06:19:13 PM [INFO]: Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pruned_heads": {},
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
#
# 09/17/2021 06:19:13 PM [INFO]: loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /root/.cache/torch/transformers/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# Model config:  {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pruned_heads": {},
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
# 09/17/2021 06:19:15 PM [INFO]: Weights of BertModel not initialized from pretrained model: ['bert.classification_layer.weight', 'bert.classification_layer.bias']
