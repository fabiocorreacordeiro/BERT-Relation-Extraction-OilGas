# %%
# Configurando Proxy

import os
from getpass import getpass

chave  = os.getenv('USER')
senha  = getpass('Senha: ')

os.environ['HTTP_PROXY']  = f'http://{chave}:{senha}@inet-sys.petrobras.com.br:804'
os.environ['HTTPS_PROXY'] = f'http://{chave}:{senha}@inet-sys.petrobras.com.br:804'
os.environ['NO_PROXY']    = '127.0.0.1, localhost, petrobras.com.br, petrobras.biz'
# Out:
# Senha:  ········

# %%
# Importando bibliotecas
import main_pretraining
import spacy

# %%
# Importando modelo do spaCy
# %run -m spacy download pt_core_news_sm
# Out:
# ✔ Download and installation successful
# You can now load the model via spacy.load('pt_core_news_sm')

# %%
nlp = spacy.load('pt_core_news_sm')

# %%
# %run main_pretraining.py --num_epochs 2 --pretrain_data 'data/corpusPublico(sem IBICT)-small.txt'
# Out:
# 09/27/2021 12:11:48 PM [INFO]: Loaded pre-training data from saved file
# 09/27/2021 12:11:48 PM [INFO]: Loaded tokenizer from saved path.
# 09/27/2021 12:11:48 PM [INFO]: Loaded 599 pre-training samples.
# 09/27/2021 12:11:48 PM [INFO]: loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /home/UPE2/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 09/27/2021 12:11:48 PM [INFO]: Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pruned_heads": {},
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
#
# 09/27/2021 12:11:59 PM [INFO]: loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /home/UPE2/.cache/torch/transformers/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# Model config:  {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pruned_heads": {},
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
# 09/27/2021 12:12:01 PM [INFO]: Weights of BertModel not initialized from pretrained model: ['bert.cls.predictions.bias', 'bert.cls.predictions.transform.dense.weight', 'bert.cls.predictions.transform.dense.bias', 'bert.cls.predictions.transform.LayerNorm.weight', 'bert.cls.predictions.transform.LayerNorm.bias', 'bert.cls.predictions.decoder.weight']
# 09/27/2021 12:12:35 PM [INFO]: Loaded checkpoint model.
# 09/27/2021 12:12:35 PM [INFO]: Loaded model and optimizer.
# 09/27/2021 12:12:35 PM [INFO]: Loaded results buffer
# 09/27/2021 12:12:35 PM [INFO]: Starting training process...
# 09/27/2021 12:12:39 PM [INFO]: Last batch samples (pos, neg): 1, 1
# LM loss, blank_loss for last batch: 0.76874, 2.33020
# [Epoch: 2,    59/ 599 points] total loss, lm accuracy per batch: 4.099, 0.586
# 09/27/2021 12:12:44 PM [INFO]: Last batch samples (pos, neg): 2, 16
# LM loss, blank_loss for last batch: 1.88430, 2.24603
# [Epoch: 2,   118/ 599 points] total loss, lm accuracy per batch: 4.110, 0.588
# 09/27/2021 12:12:48 PM [INFO]: Last batch samples (pos, neg): 1, 5
# LM loss, blank_loss for last batch: 1.56547, 2.29933
# [Epoch: 2,   177/ 599 points] total loss, lm accuracy per batch: 3.996, 0.559
# 09/27/2021 12:12:53 PM [INFO]: Last batch samples (pos, neg): 1, 16
# LM loss, blank_loss for last batch: 1.40798, 2.25994
# [Epoch: 2,   236/ 599 points] total loss, lm accuracy per batch: 4.051, 0.599
# 09/27/2021 12:12:58 PM [INFO]: Last batch samples (pos, neg): 1, 2
# LM loss, blank_loss for last batch: 1.01879, 2.14437
# [Epoch: 2,   295/ 599 points] total loss, lm accuracy per batch: 3.820, 0.621
# 09/27/2021 12:13:02 PM [INFO]: Last batch samples (pos, neg): 1, 16
# LM loss, blank_loss for last batch: 1.43326, 2.20762
# [Epoch: 2,   354/ 599 points] total loss, lm accuracy per batch: 3.714, 0.632
# 09/27/2021 12:13:07 PM [INFO]: Last batch samples (pos, neg): 2, 16
# LM loss, blank_loss for last batch: 1.93013, 2.13406
# [Epoch: 2,   413/ 599 points] total loss, lm accuracy per batch: 3.798, 0.605
# 09/27/2021 12:13:12 PM [INFO]: Last batch samples (pos, neg): 1, 16
# LM loss, blank_loss for last batch: 1.52938, 2.11328
# [Epoch: 2,   472/ 599 points] total loss, lm accuracy per batch: 3.801, 0.620
# 09/27/2021 12:13:17 PM [INFO]: Last batch samples (pos, neg): 1, 3
# LM loss, blank_loss for last batch: 0.26160, 2.19023
# [Epoch: 2,   531/ 599 points] total loss, lm accuracy per batch: 3.243, 0.736
# 09/27/2021 12:13:22 PM [INFO]: Last batch samples (pos, neg): 1, 2
# LM loss, blank_loss for last batch: 1.19782, 2.47767
# [Epoch: 2,   590/ 599 points] total loss, lm accuracy per batch: 3.459, 0.633
# Epoch finished, took 47.64 seconds.
# Losses at Epoch 2: 3.8092863
# Accuracy at Epoch 2: 0.6178708
# 09/27/2021 12:13:35 PM [INFO]: Finished Training!

# %%
model_no = 0

checkpoint_path = "./data/test_checkpoint_%d.pth.tar" % model_no
checkpoint = torch.load(checkpoint_path)

# %%
if args.use_pretrained_blanks == 1:
    logger.info("Loading model pre-trained on blanks at ./data/test_checkpoint_%d.pth.tar..." % args.model_no)
    checkpoint_path = "./data/test_checkpoint_%d.pth.tar" % args.model_no
    checkpoint = torch.load(checkpoint_path)
    model_dict = net.state_dict()
    pretrained_dict = {k: v for k, v in checkpoint['state_dict'].items() if k in model_dict.keys()}
    model_dict.update(pretrained_dict)
    net.load_state_dict(pretrained_dict, strict=False)
    del checkpoint, pretrained_dict, model_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b2fdcf6a8c3d> in <module>
#       1 #    if args.use_pretrained_blanks == 1:
# ----> 2 logger.info("Loading model pre-trained on blanks at ./data/test_checkpoint_%d.pth.tar..." % args.model_no)
#       3 checkpoint_path = "./data/test_checkpoint_%d.pth.tar" % args.model_no
#       4 checkpoint = torch.load(checkpoint_path)
#       5 model_dict = net.state_dict()
#
# NameError: name 'logger' is not defined

# %%
import torch

model_no = 0
model_size = 'bert-base-uncased'
task = 'classification'
num_classes = 2

if model_no == 0:
    from src.model.BERT.modeling_bert import BertModel as Model
    model = model_size #'bert-base-uncased'
    lower_case = True
    model_name = 'BERT'
    net = Model.from_pretrained(model, force_download=False, \
                            model_size=model_size,
                            task='classification' if task != 'fewrel' else 'fewrel',
                            n_classes_= num_classes)
# Out:
# 09/27/2021 12:14:11 PM [INFO]: loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /home/UPE2/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 09/27/2021 12:14:11 PM [INFO]: Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pruned_heads": {},
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
#
# 09/27/2021 12:14:12 PM [INFO]: loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /home/UPE2/.cache/torch/transformers/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# Model config:  {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pruned_heads": {},
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
# 09/27/2021 12:14:14 PM [INFO]: Weights of BertModel not initialized from pretrained model: ['bert.classification_layer.weight', 'bert.classification_layer.bias']

# %%
checkpoint_path = "./data/test_checkpoint_%d.pth.tar" % model_no
checkpoint = torch.load(checkpoint_path)
model_dict = net.state_dict()
pretrained_dict = {k: v for k, v in checkpoint['state_dict'].items() if k in model_dict.keys()}
model_dict.update(pretrained_dict)
#net.load_state_dict(pretrained_dict, strict=False)

# %%
net.load_state_dict(pretrained_dict, strict=False)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-09823d04491d> in <module>
# ----> 1 net.load_state_dict(pretrained_dict, strict=False)
#
# /usr/local/lib64/python3.6/site-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#    1043         if len(error_msgs) > 0:
#    1044             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# -> 1045                                self.__class__.__name__, "\n\t".join(error_msgs)))
#    1046         return _IncompatibleKeys(missing_keys, unexpected_keys)
#    1047
#
# RuntimeError: Error(s) in loading state_dict for BertModel:
# 	size mismatch for embeddings.word_embeddings.weight: copying a param with shape torch.Size([30527, 768]) from checkpoint, the shape in current model is torch.Size([30522, 768]).

# %%
# Examples:

import torch
from src.model.BERT.tokenization_bert import BertTokenizer
from src.model.BERT.modeling_bert import BertModel

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')
input_ids = torch.tensor(tokenizer.encode("Hello, my dog is cute")).unsqueeze(0)  # Batch size 1
outputs = model(input_ids)
last_hidden_states = outputs[0]  # The last hidden-state is the first element of the output tuple
input_ids
# Out:
# 09/27/2021 12:19:24 PM [INFO]: https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt not found in cache or force_download set to True, downloading to /tmp/tmptv8tghgm
# 100%|██████████| 231508/231508 [00:01<00:00, 126638.31B/s]
# 09/27/2021 12:19:27 PM [INFO]: copying /tmp/tmptv8tghgm to cache at /home/UPE2/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 09/27/2021 12:19:27 PM [INFO]: creating metadata file for /home/UPE2/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 09/27/2021 12:19:27 PM [INFO]: removing temp file /tmp/tmptv8tghgm
# 09/27/2021 12:19:27 PM [INFO]: loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /home/UPE2/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# 09/27/2021 12:19:27 PM [INFO]: loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /home/UPE2/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 09/27/2021 12:19:27 PM [INFO]: Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pruned_heads": {},
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
#
# 09/27/2021 12:19:28 PM [INFO]: loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /home/UPE2/.cache/torch/transformers/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-078b288ed073> in <module>
#       6
#       7 tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# ----> 8 model = BertModel.from_pretrained('bert-base-uncased')
#       9 input_ids = torch.tensor(tokenizer.encode("Hello, my dog is cute")).unsqueeze(0)  # Batch size 1
#      10 outputs = model(input_ids)
#
# /projetos/UPE2/BERT-Relation-Extraction-OilGas/src/model/BERT/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     390
#     391         # Instantiate model.
# --> 392         model = cls(config, *model_args, **model_kwargs)
#     393
#     394         if state_dict is None and not from_tf:
#
# TypeError: __init__() missing 1 required positional argument: 'model_size'

# %%
from src.model.BERT.modeling_bert import BertModel as Model
model = 'bert-base-uncased' #args.model_size #
lower_case = True
model_name = 'BERT'
net = Model.from_pretrained(model, force_download=False, \
                        model_size= 'bert-base-uncased', #args.model_size,
                        task='classification',# if args.task != 'fewrel' else 'fewrel',\
                        n_classes_= 2)# args.num_classes)
# Out:
# 09/24/2021 09:26:58 AM [INFO]: loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /home/UPE2/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 09/24/2021 09:26:58 AM [INFO]: Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pruned_heads": {},
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
#
# 09/24/2021 09:26:58 AM [INFO]: loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-pytorch_model.bin from cache at /home/UPE2/.cache/torch/transformers/aa1ef1aede4482d0dbcd4d52baad8ae300e60902e88fcb0bebdec09afd232066.36ca03ab34a1a5d5fa7bc3d03d55c4fa650fed07220e2eeebc06ce58d0e9a157
# Model config:  {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pruned_heads": {},
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 30522
# }
# 09/24/2021 09:27:00 AM [INFO]: Weights of BertModel not initialized from pretrained model: ['bert.classification_layer.weight', 'bert.classification_layer.bias']
